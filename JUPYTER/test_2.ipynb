# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('Downloads/me.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=710x710 at 0x7F2A54030208>

# %%
pic_arr = np.asarray(pic)

# %%
pic_arr
# Out:
# array([[[130, 132, 206],
#         [130, 132, 206],
#         [129, 131, 205],
#         ...,
#         [118, 117, 195],
#         [118, 117, 195],
#         [118, 117, 195]],
#
#        [[130, 132, 206],
#         [130, 132, 206],
#         [129, 131, 205],
#         ...,
#         [119, 118, 196],
#         [119, 118, 196],
#         [119, 118, 196]],
#
#        [[130, 132, 206],
#         [130, 132, 206],
#         [129, 131, 205],
#         ...,
#         [121, 120, 198],
#         [121, 120, 198],
#         [121, 120, 198]],
#
#        ...,
#
#        [[ 62,  73, 127],
#         [ 60,  71, 125],
#         [ 59,  70, 124],
#         ...,
#         [ 44,  60, 109],
#         [ 44,  60, 109],
#         [ 44,  60, 109]],
#
#        [[ 62,  73, 127],
#         [ 60,  71, 125],
#         [ 59,  70, 124],
#         ...,
#         [ 44,  60, 109],
#         [ 44,  60, 109],
#         [ 44,  60, 109]],
#
#        [[ 62,  73, 127],
#         [ 60,  71, 125],
#         [ 59,  70, 124],
#         ...,
#         [ 44,  60, 109],
#         [ 44,  60, 109],
#         [ 44,  60, 109]]], dtype=uint8)

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (710, 710, 3)

# %%
plt.imshow(pic_arr)

# %%
pic = Image.open('Downloads/puppy.jpeg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=990x792 at 0x7F2A4288CDA0>

# %%
pic_arr = np.asarray(pic)

# %%
pic_arr
# Out:
# array([[[ 77,  51,  52],
#         [ 77,  51,  52],
#         [ 77,  51,  52],
#         ...,
#         [ 57,  37,  39],
#         [ 57,  37,  39],
#         [ 57,  37,  39]],
#
#        [[ 77,  51,  52],
#         [ 77,  51,  52],
#         [ 77,  51,  52],
#         ...,
#         [ 57,  37,  39],
#         [ 57,  37,  39],
#         [ 57,  37,  39]],
#
#        [[ 77,  51,  52],
#         [ 77,  51,  52],
#         [ 77,  51,  52],
#         ...,
#         [ 57,  37,  39],
#         [ 57,  37,  39],
#         [ 57,  37,  39]],
#
#        ...,
#
#        [[179, 185, 199],
#         [179, 185, 199],
#         [179, 185, 199],
#         ...,
#         [100, 102,  88],
#         [101, 103,  89],
#         [100, 102,  88]],
#
#        [[184, 190, 204],
#         [183, 189, 203],
#         [183, 189, 203],
#         ...,
#         [101, 103,  89],
#         [101, 103,  89],
#         [101, 103,  89]],
#
#        [[186, 192, 206],
#         [186, 192, 206],
#         [185, 191, 205],
#         ...,
#         [101, 103,  89],
#         [102, 104,  90],
#         [102, 104,  90]]], dtype=uint8)

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (792, 990, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
pic_red.shape
# Out:
# (792, 990, 3)

# %%
plt.imshow(pic_red[:,:,0] , cmap = 'gray')

# %%
plt.imshow(pic_red[:,:,1] , cmap = 'gray')

# %%
plt.imshow(pic_red[:,:,2] , cmap = 'gray')

# %%
pic = Image.open('Downloads/puppy_3.jpeg')

# %%
pic_arr = np.asarray(pic)

# %%
pic_arr
# Out:
# array([[[ 68,  81,  35],
#         [ 68,  81,  35],
#         [ 66,  79,  33],
#         ...,
#         [ 71,  83,  33],
#         [ 75,  87,  37],
#         [ 75,  88,  35]],
#
#        [[ 67,  80,  34],
#         [ 66,  79,  33],
#         [ 65,  78,  32],
#         ...,
#         [ 71,  83,  33],
#         [ 75,  87,  37],
#         [ 75,  88,  35]],
#
#        [[ 65,  78,  32],
#         [ 65,  78,  32],
#         [ 63,  76,  30],
#         ...,
#         [ 70,  82,  32],
#         [ 74,  87,  34],
#         [ 74,  87,  34]],
#
#        ...,
#
#        [[243, 242, 250],
#         [249, 248, 255],
#         [240, 239, 247],
#         ...,
#         [240, 239, 247],
#         [245, 244, 252],
#         [245, 244, 252]],
#
#        [[243, 242, 250],
#         [251, 250, 255],
#         [241, 240, 248],
#         ...,
#         [243, 242, 250],
#         [245, 244, 252],
#         [244, 243, 251]],
#
#        [[240, 239, 247],
#         [250, 249, 255],
#         [239, 238, 246],
#         ...,
#         [245, 244, 252],
#         [245, 244, 252],
#         [243, 242, 250]]], dtype=uint8)

# %%
pic_arr.shape
# Out:
# (328, 474, 3)

# %%
pic.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-c757483c6502> in <module>
# ----> 1 pic.shape
#
# AttributeError: 'JpegImageFile' object has no attribute 'shape'

# %%
pic_arr.shape
# Out:
# (328, 474, 3)

# %%
plt.imshow(pic_arr)

# %%
plt.imshow(pic_arr[:,:,0], cmap = 'gray')

# %%
plt.imshow(pic_arr[:,:,1] , cmap = 'gray')

# %%
plt.imshow(pic_arr[:,:,1] , cmap = 'gray')

# %%
pic_red[:,:,1] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red = pic_arr.copy()

# %%
pic_red[:,:,1] = 0

# %%
pic_red[:,:,2] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red[:,:,0] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (328, 474, 3)

# %%
pic_red[:,:,0].shape
# Out:
# (328, 474)
