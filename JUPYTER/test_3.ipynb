# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('Downloads/puppy_3.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (328, 474, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('Downloads/puppy_3.jpeg' , cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray , cmap = 'gray')

# %%
img_gray.shape
# Out:
# (328, 474)

# %%
img_gray.min()
# Out:
# 6

# %%
img_gray.max()
# Out:
# 255

# %%
fix_img.shape
# Out:
# (328, 474, 3)

# %%
plt.imshow(fix_img)

# %%
img
# Out:
# array([[[ 35,  81,  68],
#         [ 35,  81,  68],
#         [ 33,  79,  66],
#         ...,
#         [ 33,  83,  71],
#         [ 35,  88,  75],
#         [ 35,  88,  75]],
#
#        [[ 34,  80,  67],
#         [ 33,  79,  66],
#         [ 32,  78,  65],
#         ...,
#         [ 33,  83,  71],
#         [ 35,  88,  75],
#         [ 35,  88,  75]],
#
#        [[ 32,  78,  65],
#         [ 32,  78,  65],
#         [ 30,  76,  63],
#         ...,
#         [ 32,  82,  70],
#         [ 34,  87,  74],
#         [ 34,  87,  74]],
#
#        ...,
#
#        [[250, 242, 243],
#         [255, 248, 249],
#         [247, 239, 240],
#         ...,
#         [247, 239, 240],
#         [252, 244, 245],
#         [252, 244, 245]],
#
#        [[250, 242, 243],
#         [255, 250, 251],
#         [248, 240, 241],
#         ...,
#         [250, 242, 243],
#         [252, 244, 245],
#         [251, 243, 244]],
#
#        [[247, 239, 240],
#         [255, 249, 250],
#         [246, 238, 239],
# ...

# %%
plt.showim(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-3ecc44731b20> in <module>
# ----> 1 plt.showim(img)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'showim'

# %%
plt.showim(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-3ecc44731b20> in <module>
# ----> 1 plt.showim(img)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'showim'

# %%
plt.imshow(img)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (328, 474, 3)

# %%
reaized_img = cv2.resize(fix_img,(200,150))

# %%
plt.imshow(reaized_img)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
fix_img.shape
# Out:
# (328, 474, 3)

# %%
new_img.shape
# Out:
# (164, 237, 3)

# %%
flip_img = cv2.flip(fix_img,0)

plt.imshow(flip_img)

# %%
flip_img = cv2.flip(fix_img,-1)

plt.imshow(flip_img)

# %%
cv2.imwrite('new_image.jpg',fix_img)
# Out:
# True

# %%
plt.imshow(fix_img)

# %%
revs_img_fix_save = cv2.cvtColor(fix_img,cv2.COLOR_RGB2BGR)

# %%
plt.imshow(revs_img_fix_save)

# %%
cv2.imwrite('new.jpg', revs_img_fix_save)
# Out:
# True

# %%
plt.imsave('new_plt_save.jpg', fix_img)

# %%
### TEST

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
